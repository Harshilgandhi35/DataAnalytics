# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1.	Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates
df = pd.read_csv('alphabet_stock_data.csv')
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf = (df['Date'] >= startDate) & (df['Date'] <= endDate)
newdf = df.loc[newdf]
newdf.plot(x='Date',y=['Open','Close'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(' line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates')
# Out:
# Text(0.5, 1.0, ' line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates')

# %%
#a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf = (df['Date'] >= startDate) & (df['Date'] <= endDate)
newdf = df.loc[newdf]
newdf.plot(x='Date',y='Close')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(' line plot of the  closing stock prices of Alphabet Inc. between two specific dates')
# Out:
# Text(0.5, 1.0, ' line plot of the  closing stock prices of Alphabet Inc. between two specific dates')

# %%
#3.	Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df3 = df.loc[newdf]
df4 = df3.set_index('Date')
df4['Volume'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates

# %%
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf2 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df6 = df.loc[newdf2]
df6.plot.bar(x='Date',y=['Open','Close'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Pandas program to create a stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates. 
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf2 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df6 = df.loc[newdf2]
df6.plot.bar(x='Date',y=['Open','Close'],stacked=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 6 Write a Pandas program to create a horizontal stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates. 
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf2 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df6 = df.loc[newdf2]
df6.plot.barh(x='Date',y=['Open','Close'],stacked=True)
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
#7.a Pandas program to create a histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates. 
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf3 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df7 = df.loc[newdf3]
df8 = df7[['Open','Close','High','Low']]
df8.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#8.Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf3 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df7 = df.loc[newdf3]
df8 = df7[['Open','Close','High','Low']]
df8.plot.hist(stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#9.Write a Pandas program to draw a horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc. between two specific dates. 
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf4 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df9 = df.loc[newdf3]
df10 = df7['Open']
df10.plot.hist(orientation='horizontal',cumulative=True)
plt.title('horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc')
# Out:
# Text(0.5, 1.0, 'horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc')

# %%
#10.Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates with more bins. 
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf5 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df11 = df.loc[newdf5]
df12 = df7[['Open','Close','High','Low']]
plt.figure(figsize=(20,20))
df12.plot.hist(stacked=True,bins=25)
plt.title(' stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc ')
# Out:
# Text(0.5, 1.0, ' stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc ')

# %%
#11 Write a Pandas program to create a stacked histograms plot with more bins of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates. 
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf5 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df11 = df.loc[newdf5]
df12 = df7[['Open','Close','High','Low']]
plt.figure(figsize=(20,20))
df12.hist()
plt.suptitle(' stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc ')
# Out:
# Text(0.5, 0.98, ' stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc ')

# %%
#12 Write a Pandas program to create a plot of stock price and trading volume of Alphabet Inc. between two specific dates.
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf2 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df6 = df.loc[newdf2]
#figure, axis = plt.subplots(1, 1)
#df6.plot(title='Volume',subplots=True,figsize=(10,10))
fig, axes = plt.subplots(nrows=2, ncols=1)
df6['Close'].plot(ax=axes[0],title='Close')

df6['Volume'].plot(ax=axes[1],title='Volume')
# Out:
# <AxesSubplot:title={'center':'Volume'}>

# %%
#13.Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. between two specific dates.
startDate = pd.to_datetime('2020-04-01')
endDate = pd.to_datetime('2020-05-07')
df['Date'] = pd.to_datetime(df['Date'])
newdf2 = (df['Date'] >= startDate) & (df['Date'] <= endDate)
df6 = df.loc[newdf2]
fig, axes = plt.subplots(nrows=3, ncols=2)
fig.tight_layout(pad=2.0)#use to adjust the graphs padding
df6['Open'].plot(ax=axes[0,0],title='Open',grid='True')
df6['High'].plot(ax=axes[0,1],title='High',grid='True')
df6['Low'].plot(ax=axes[1,0],title='Low',grid='True')
df6['Close'].plot(ax=axes[1,1],title='Close',grid='True')
df6['Adj Close'].plot(ax=axes[2,0],title='Adj Close',grid='True')
df6['Volume'].plot(ax=axes[2,1],title='Volume',grid='True')
# Out:
# <AxesSubplot:title={'center':'Volume'}>

# %%
#14.Write a Pandas program to create a plot of adjusted closing prices, thirty days and forty days simple moving average of Alphabet Inc. between two specific dates. 
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("alphabet_stock_data.csv")
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-9-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
stock_data = df1.set_index('Date')
close_px = stock_data['Adj Close']
stock_data['SMA_30_days'] = stock_data['Close'].rolling(window=30).mean() 
stock_data['SMA_40_days'] = stock_data['Close'].rolling(window=40).mean()
plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('Historical stock prices of Alphabet Inc. [01-04-2020 to 30-09-2020]\n',fontsize=18, color='black')
plt.plot(stock_data['Adj Close'],label='Adjusted Closing Price', color='black')
plt.plot(stock_data['SMA_30_days'],label='30 days simple moving average', color='red')
plt.plot(stock_data['SMA_40_days'],label='40 days simple moving average', color='green')
plt.legend(loc=2)#it will show which line is for
plt.show()

# %%
#15.

# %%
#15.Write a Pandas program to create a plot of adjusted closing prices, 30 days simple moving average and exponential moving average of Alphabet Inc. between two specific dates. 
df = pd.read_csv("alphabet_stock_data.csv")
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-9-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
stock_data = df1.set_index('Date')
close_px = stock_data['Adj Close']
stock_data_30 = stock_data['Close'].rolling(window=30).mean() 
stock_data_exp = stock_data['Close'].ewm(span=20).mean()#ewm is  exponentially weighted
plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('adjusted closing prices, 30 days simple moving average and exponential moving average of Alphabet Inc.')
plt.plot(close_px,label='adj close',color='black')
plt.plot(stock_data_30,label='sma of 30 days',color='red')
plt.plot(stock_data_exp,label='ema for 30 days',color='green')
plt.legend(loc=2)
plt.show()

# %%
#16.Write a Pandas program to create a scatter plot of the trading volume/stock prices of Alphabet Inc. stock between two specific dates.
start_date=pd.to_datetime('2020-04-01')
end_date=pd.to_datetime('2020-09-30')
df['Date'] = pd.to_datetime(df['Date'])
newdf=(df['Date']>=start_date)&(df['Date']<=end_date)
df11 = df.loc[newdf]
x = ['Close']
y = ['Volume']

df11.plot.scatter(x,y,xlabel='Close',ylabel='Volume',figsize=(10,10),title='a scatter plot of the trading volume/stock prices of Alphabet Inc.')
# Out:
# <AxesSubplot:title={'center':'a scatter plot of the trading volume/stock prices of Alphabet Inc.'}, xlabel='Close', ylabel='Volume'>

# %%
#17.Write a Pandas program to create a plot to visualize daily percentage returns of Alphabet Inc. stock price between two specific dates. 
df = pd.read_csv("alphabet_stock_data.csv")
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-9-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
df2 = df1[['Date', 'Adj Close']]
df3 = df2.set_index('Date')
daily_changes = df3.pct_change(periods=1)
daily_changes['Adj Close'].plot(figsize=(10,7),legend=True,linestyle='--',marker='o',grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#
